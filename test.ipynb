# %%
from utils import get_models_for_testing, test_image

# %%
# Load trained models
gen, _ = get_models_for_testing()
# Out:
# Check Generator's model architecture
# Model: "generator"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 1, 1, 5)      0           input_5[0][0]
# __________________________________________________________________________________________________
# tf.cast_1 (TFOpLambda)          (None, 1, 1, 5)      0           tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# ...

# %%
"""
[test_image args]
    model: a generator model
    fpath: a test image path
    to_black_hair(bool): a flag whether to make your image into black hair
    to_blond_hair(bool): a flag whether to make your image into blond hair
    to_brown_hair(bool): a flag whether to make your image into brown hair
    to_male(bool): a flag whether to make your image into male
    to_young(bool): a flag whether to make your image into young
"""

# Specify your image path to test below
img_path = "./test.jpg"

#(e.g.) To make the image into blond hair
test_image(model=gen,
           fpath=img_path, 
           to_black_hair=False, 
           to_blond_hair=True, 
           to_brown_hair=False, 
           to_male=True, 
           to_young=True)
